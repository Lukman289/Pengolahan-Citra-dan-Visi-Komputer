# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukman289/Pengolahan-Citra-dan-Visi-Komputer/blob/main/Modul_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# Membuat list untuk menyimpan url dari beberapa image
urls = ["http://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "http://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://assets.rebelmouse.io/eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpbWFnZSI6Imh0dHBzOi8vYXNzZXRzLnJibC5tcy80MTQwNzA5L29yaWdpbi5qcGciLCJleHBpcmVzX2F0IjoxNzI4MDQ5MjAyfQ.HCk1uahPNm1ne0lNFZxAABdwt_kuuKHus9ZBXDlsqRA/img.jpg?width=980&quality=85"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')

tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi timage: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

print("\n")
#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=980x596>
# resolusi timage: tinggi x lebar =  596  x  490
# <PIL.Image.Image image mode=RGB size=490x596>
# <PIL.Image.Image image mode=RGB size=980x596>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
# Jawaban
#
# Karena google colab dapat digunakan dengan gratis dan tidak memerlukan penyimpanan storage untuk menginstallnya.
#
# ---
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# Jawaban
#
# *   numpy: digunakan untuk operasi numerik di phython, terutama pada array multidimensi
# *   pandas: digunakan untuk menganalisis data
# *   cv2: OpenCV, library ini digunakan untuk pengolahan gambar dan video
# *   google.colab.patches.cv2_imshow: Patch ini digunakan untuk menampilkan gambar pada google colab
# *   skimage.io: digunakan untuk membaca dan menulis gambar
# *   skimage.transform: digunakan untuk trensformasi gambar
# *   PIL.Image: library ini digunakan untuk pengolahan gambar dan menyediakan tools untuk memanipulasi gambar
# *   matplotlib.pylab: library ini digunakan untuk membuat visualisasi data, termasuk plotting gambar
#
# ---
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# ![Screenshot 2024-09-03 094937.png](data:image/png;base64,...)
#
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# Jawaban
#
# Kode tersebut digunakan untuk memberikan garis horizontal yang ada pada tengah gambar, untuk menentukan posisi penempatan garis pada kode tersebut dilakukan pembagian kepada tinggi dari gambar tersebut.
#
# ---
# 4. Perhatikan potongan kode progam berikut :
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Jawaban
#
# Kode tersebut digunakan untuk menentukan warna dari garis horizontal. 3 angka tersebut mewakili kode warna RGB.
#
# ---
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawaban
#
# Keterkaitan antara resolusi dengan pixel adalah jumlah pixel yang digunakan, jika jumlah pixel yang digunakan lebih banyak maka detail atau resolusi dari gambar akan menjadi tinggi, sebaliknya jika jumlah pixel yang digunakan lebih sedikit maka resolusi dari gambar juga akan menurun.
