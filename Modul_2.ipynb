# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukman289/Pengolahan-Citra-dan-Visi-Komputer/blob/main/Modul_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
# drive.mount('/content/drive')

# %%
import cv2 as cv
from google. colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Kuliah /Semester 5/Pengolahan Citra dan Visi Komputer/img/kitten1.jpeg')
plt. imshow(img)
# cv2_imshow(img)
#perhatikan hasilnya adalah citra dgn channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #Konversi channel BRG -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Kuliah /Semester 5/Pengolahan Citra dan Visi Komputer/img/kitten1.jpeg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(img_gray,cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.inwrite('/content/drive/MyDrive/Kuliah /Semester 5/Pengolahan Citra dan Visi Komputer/img/kitten2.jpeg', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros((512,512,3),dtype=np.uint16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=25,color=(255,0,0),thickness=50)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros((512,512,3),dtype=np.uint32)
plt.imshow(black_img2)

# %%
vertices = np.array([
    [100,300],
    [200,200],
    [400,300],
    [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang memiliki R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
# black_img2 = black_img2.astype(np.uint8)
black_img2 = black_img2.astype(np.uint8)
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **Pertanyaan**

# %% [markdown]
# 1. Apakah Perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# > perbedaan yang terdapat pada gambar yang menggunakan matplotlib akan menampilkan ukuran gambar pada sisi-sisi gambar.
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# > perbedaan yang antara tipe gambar int16 dengan in32 adalah terletak pada saat kita memanipulasi gambar, pada gambar bertype int16 akan mengalami overflow, sedangkan pada gambar bertype 32 tidak akan mengalami masalah tersebut.
#
# ```
# from google.colab.patches import cv2_imshow
# from skimage import io
# ```
# 3. Apakah kegunaan "google.colab.patches import cv2_imshow" pada potongan kode di atas
# > kegunaan library tersebut adalah untuk menampilkan objek yang diinginkan.
#
# 4. Apakah kegunaan "skimage import io" pada potongan kode soal nomor 3
# > library tersebut digunakan untuk membaca dan menulis gambar.

# %%
ktp = cv.imread('/content/drive/MyDrive/Kuliah /Semester 5/Pengolahan Citra dan Visi Komputer/img/ktp_2.jpg')
ktp = cv.cvtColor(ktp,cv.COLOR_BGR2RGB)
cv.circle(ktp,center=(483,150),radius=15,color=(255,0,0),thickness=5)
cv.circle(ktp,center=(525,150),radius=15,color=(0,255,0),thickness=5)
cv.circle(ktp,center=(505,195),radius=15,color=(0,0,255),thickness=5)
plt.imshow(ktp)
